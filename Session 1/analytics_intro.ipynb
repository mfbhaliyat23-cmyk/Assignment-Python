# %%
"""Assignment:- 

    1) Session 1 : """

print("My name is Mohammad Bhaliyat") 
print("My favourite app is Instagram")
# Out:
# My name is Mohammad Bhaliyat
# My favourite app is Instagram

# %%
import datetime
print("Current Year :" , datetime.datetime.now().year)
# Out:
# Current Year : 2026
